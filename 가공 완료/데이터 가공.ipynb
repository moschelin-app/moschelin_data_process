# %%
import pandas as pd
import numpy as np

# %%
place_df1 = pd.read_csv('/content/drive/MyDrive/모슐랭 프로젝트 데이터 가공/place인천 강화군 맛집.csv')
review_df1 = pd.read_csv('/content/drive/MyDrive/모슐랭 프로젝트 데이터 가공/reivew인천 강화군 맛집.csv')

# %%
place_df1
# Out:
#      id          name      sub_name                          addr         lat  \
# 0     0  강화도맛집 숯불생선구이       생선 레스토랑       인천광역시 강화군 길상면 해안동로 14-6  37.6282482
# 1     1         등나무가든           음식점       인천광역시 강화군 길상면 초지리 622-1  37.6341853
# 2     2        등대숯불장어           음식점         인천광역시 강화군 길상면 초지로 142  37.6279993
# 3     3       강나루숯불장어  민물장어 요리 전문식당    인천광역시 강화군 길상면 초지리 1251-573  37.6206539
# 4     4          강화맛집           한식당  길상면 온수리 412-2번지 강화군 인천광역시 KR  37.6383857
# ..  ...           ...           ...                           ...         ...
# 66  110          황금수라           음식점  인천광역시 강화군 양도면 인산리 788-2번지 1층  37.7012357
# 67  112          미락횟집           음식점       인천광역시 강화군 화도면 내리 1825-5  37.6396544
# 68  114         봉가돈까스           음식점       인천광역시 강화군 강화읍 용정리 664-1  37.7390854
# 69  116        큰이모네식당           음식점       인천광역시 강화군 선원면 냉정리 229-1  37.7112968
# 70  118           원두막           한식당                         인천광역시  37.6345733
#
#             lng
# ...

# %%
new_id = place_df1['id'].max() + 1
new_id
# Out:
# 119

# %%
review_df1
# Out:
#      reivewId                                            content  \
# 0           0    생선도 싱싱하고 숯불이 좋아\r\n맛이 좋네요.\r\n메인 생선요리가 따로 나왔는데…
# 1           0  검색해서 간 곳이예요\r\n생선을 숯불에 구우니\r\n이렇게 맛이있구나 3인분을 3명이…
# 2           0  냉동생선이 아니고 생물 생선을 숯불에 구어 고기가 아주 부드럽고 숯불 향이 제대로입...
# 3           0  깔끔함은 바라지않고 맛만보고 간다면 나쁘지않음.\r\n초벌구이한 생선이 나오면  숯...
# 4           0  모듬생선구이₩16.000~계절따라 그때그때 나오는 많이 나오는 생선으로 주시는것같아...
# ..        ...                                                ...
# 325       118  세트 시켜먹었는데 젓국갈비랑 돌솥밥 돼지갈비가 구워서 나온다\r\n\r\n젓국갈비는...
# 326       118  갑은 숯불자연포크(돼지갈비).90년대 돼지갈비맛. 젓국갈비전골은 호불호가 많이 갈리...
# 327       118  젓국갈비와 돼지갈비, 돌솥밥 등 모든 음식이 맛있습니다.\r\n방역수칙도 잘 지켜지...
# 328       118  기대안하고 먹으러갔는데 진짜 맛집이에요!\r\n도토리묵, 자연포크, 솥밥 전부 다 ...
# 329       118  맛있었다. 자극적이거나 짜지않고 간도 적당하고 커플세트 먹었는데 양이 상당했다. 재...
#
#                                                  image  star
# 0    https://lh5.googleusercontent.com/p/AF1QipOug3...     4
# 1    https://lh5.googleusercontent.com/p/AF1QipPObL...     5
# ...

# %%
place_df2 = pd.read_csv('/content/drive/MyDrive/모슐랭 프로젝트 데이터 가공/place인천 계양구 맛집.csv')
review_df2 = pd.read_csv('/content/drive/MyDrive/모슐랭 프로젝트 데이터 가공/reivew인천 계양구 맛집.csv')

# %%
place_df2['id'] += new_id
place_df2
# Out:
#       id             name        sub_name                     addr  \
# 0    119  전민규의황제누룽지탕(계양점)             한식당     인천광역시 계양구 계산동 1082-2
# 1    120           누룩골계양점             음식점       인천광역시 계양구 경명대로 954
# 2    121         가든파티 계양점       갈비 전문 음식점       인천광역시 계양구 경명대로 977
# 3    122          경복궁 계산점             한식당  인천광역시 계양구 계산동 1083-6 나동
# 4    123       경복궁불고기 계산점         불고기 전문점      인천광역시 계양구 작전동 910-2
# ..   ...              ...             ...                      ...
# 115  234            옛날떡볶이             음식점      인천광역시 계양구 임학동 46-38
# 116  235          신선수제돈까스        돈까스 전문식당    인천광역시 계양구 임학동 장제로 881
# 117  236              소왔쏘  한국식 소고기 전문 음식점    인천광역시 계양구 임학동 67번지 1층
# 118  237             천주채관          중국 음식점                    인천광역시
# 119  238             맷돌로만       두부 요리 전문점                    인천광역시
#
#             lat          lng
# 0    37.534673!  126.737133!
# 1    37.5443412  126.7126246
# 2    37.544598!  126.7154767
# 3    37.534352!  126.73757!1
# ...

# %%
review_df2['reivewId'] += new_id
review_df2
# Out:
#      reivewId                                            content  \
# 0         119  기본 누룽지탕 주문하면 정말 바로바로 나옵니다. 가격대도 높지않아서 근처에 살면서 ...
# 1         119  누룽지가 눅눅해지지않게 바로 누룽지위에 탕을 부어줘요. 용암처럼 끓는 뚝배기가 좀 ...
# 2         119                      우연히 방문했었는데여\r\n해물누룽탕 대박입니다~~…
# 3         119  맛은 글쎄요? 그냥 무난한 정도? 음식점 크기는 크고 손님도 많았다! 한식도 아니고...
# 4         119                          해물누룽지탕\r\n전주돌솥밥\r\n찾쌀탕수육…
# ..        ...                                                ...
# 593       238  두부가맛있다. 두부 콩 음식이 넘 맛있다. 단. 막친절하진않고. 그냥 뭐 평범. 음...
# 594       238  간날은 어르신이 하느라 좀 느린 편이엇음. 달걀 지진 음식들 고소하니 맛남. 두부채...
# 595       238  여기서 두부명태조림 먹었는데\r\n훼스탈4알까스명수2병 먹었습니다!\r\n집사람이랑...
# 596       238      계양산밑 두부전문집\r\n직접 만든 두부 맛있어요\r\n4명이 정식2  순두부2…
# 597       238  순두부 정식 먹어봤습니다.\r\n식전에 순두부 한그릇 나오구요\r\n정식에는 수육과...
#
#                                                  image  star
# 0    https://lh5.googleusercontent.com/p/AF1QipOeAg...     4
# 1    https://lh5.googleusercontent.com/p/AF1QipNbsh...     4
# ...

# %%
new_place_df = pd.concat([place_df1, place_df2], ignore_index=True)
new_place_df
# Out:
#       id          name        sub_name                          addr  \
# 0      0  강화도맛집 숯불생선구이         생선 레스토랑       인천광역시 강화군 길상면 해안동로 14-6
# 1      1         등나무가든             음식점       인천광역시 강화군 길상면 초지리 622-1
# 2      2        등대숯불장어             음식점         인천광역시 강화군 길상면 초지로 142
# 3      3       강나루숯불장어    민물장어 요리 전문식당    인천광역시 강화군 길상면 초지리 1251-573
# 4      4          강화맛집             한식당  길상면 온수리 412-2번지 강화군 인천광역시 KR
# ..   ...           ...             ...                           ...
# 186  234         옛날떡볶이             음식점           인천광역시 계양구 임학동 46-38
# 187  235       신선수제돈까스        돈까스 전문식당         인천광역시 계양구 임학동 장제로 881
# 188  236           소왔쏘  한국식 소고기 전문 음식점         인천광역시 계양구 임학동 67번지 1층
# 189  237          천주채관          중국 음식점                         인천광역시
# 190  238          맷돌로만       두부 요리 전문점                         인천광역시
#
#             lat          lng
# 0    37.6282482  126.5325893
# 1    37.6341853  126.5312613
# 2    37.6279993  126.5328668
# ...

# %%
new_review_df = pd.concat([review_df1, review_df2], ignore_index=True)
new_review_df
# Out:
#      reivewId                                            content  \
# 0           0    생선도 싱싱하고 숯불이 좋아\r\n맛이 좋네요.\r\n메인 생선요리가 따로 나왔는데…
# 1           0  검색해서 간 곳이예요\r\n생선을 숯불에 구우니\r\n이렇게 맛이있구나 3인분을 3명이…
# 2           0  냉동생선이 아니고 생물 생선을 숯불에 구어 고기가 아주 부드럽고 숯불 향이 제대로입...
# 3           0  깔끔함은 바라지않고 맛만보고 간다면 나쁘지않음.\r\n초벌구이한 생선이 나오면  숯...
# 4           0  모듬생선구이₩16.000~계절따라 그때그때 나오는 많이 나오는 생선으로 주시는것같아...
# ..        ...                                                ...
# 488        51                      베이컨 새우볶음밥이 인상적이네요. 하이볼도 좋았구요.
# 489        51  부평점도 좋았지만 구월점은 또 색다르게 따뜻한 분위기의 가게여서 너무 좋았습니다. ...
# 490        51                                 너무 맛있습니다. 적극추천합니다.
# 491        51                    파스타 맛집 인정 .. 사장님을 포함한 모든 분들 왕친절
# 492        51                 음식들 전체적으로 무난하고 직원분들 친절했습니다 조명이 좋네요
#
#                                                  image  star
# 0    https://lh5.googleusercontent.com/p/AF1QipOug3...     4
# 1    https://lh5.googleusercontent.com/p/AF1QipPObL...     5
# ...

# %%
new_id = new_place_df['id'].max() + 1
new_id
# Out:
# 239

# %%
place_df3 = pd.read_csv('/content/drive/MyDrive/모슐랭 프로젝트 데이터 가공/place인천 남동구 맛집.csv')
review_df3 = pd.read_csv('/content/drive/MyDrive/모슐랭 프로젝트 데이터 가공/reivew인천 남동구 맛집.csv')

# %%
place_df3
# Out:
#      id                   name      sub_name  \
# 0   239                   부암갈비     갈비 전문 음식점
# 1   240                   로로김밥           한식당
# 2   241                  곤드레밥집           한식당
# 3   242                육해공생칼국수          칼국수집
# 4   243                    전복촌           음식점
# 5   244                 파니노구스토      이탈리아 음식점
# 6   245                  초심 본점           음식점
# 7   246                  공단떡볶이           음식점
# 8   247                 삼만시두부집     두부 요리 전문점
# 9   248              착한식당 착한게장           음식점
# 10  249            영월애곤드레 인천본점           한식당
# 11  250                 황금풍천장어  민물장어 요리 전문식당
# 12  251                경복궁 구월점           한식당
# 13  252                    사도시         회 전문점
# 14  253  이당 비스트로 Yidang Bistro           음식점
# 15  254                등촌샤브칼국수      샤브샤브 전문점
# 16  255                    인천집           한식당
# 17  256                  간석동맛집           음식점
# 18  257                  작은식당우     일본라면 전문식당
# 19  258                    삼화정           음식점
# ...

# %%
review_df3
# Out:
#      reivewId                                            content  \
# 0         239  웨이팅이 좀 있어요 유명한곳이라 웨이팅하는 곳도 있어서 편히 기다릴수 있어요\r\n...
# 1         239  돼지갈비가 담백하고 먹는방법에 따라 다른 맛이 납니다. 직원분들이 알맞게 구워주어 ...
# 2         239  5시땡하고 드갔더니 아슬아슬하게 웨이팅\r\n피했네요. 심지어 평일이요. .하하\r...
# 3         239  일요일이라 12시에 딱 갔는데도 웨이팅했네요. 1시간 조금 넘게 기다려서 들어갔습니...
# 4         239  생갈비가 진짜 맛있네요 육즙도 가득이고 젓갈비빔밥도 맛있습니다. 일하시는분들도 친절...
# ..        ...                                                ...
# 158       290                      베이컨 새우볶음밥이 인상적이네요. 하이볼도 좋았구요.
# 159       290  부평점도 좋았지만 구월점은 또 색다르게 따뜻한 분위기의 가게여서 너무 좋았습니다. ...
# 160       290                                 너무 맛있습니다. 적극추천합니다.
# 161       290                    파스타 맛집 인정 .. 사장님을 포함한 모든 분들 왕친절
# 162       290                 음식들 전체적으로 무난하고 직원분들 친절했습니다 조명이 좋네요
#
#                                                  image  star
# 0    https://lh5.googleusercontent.com/p/AF1QipPo2T...     5
# 1    https://lh5.googleusercontent.com/p/AF1QipPo9L...     5
# ...

# %%
place_df3['id'] += new_id
review_df3['reivewId'] += new_id

# %%
new_place_df = pd.concat([new_place_df, place_df3], ignore_index=True)
new_place_df
# Out:
#       id          name      sub_name                            addr  \
# 0      0  강화도맛집 숯불생선구이       생선 레스토랑         인천광역시 강화군 길상면 해안동로 14-6
# 1      1         등나무가든           음식점         인천광역시 강화군 길상면 초지리 622-1
# 2      2        등대숯불장어           음식점           인천광역시 강화군 길상면 초지로 142
# 3      3       강나루숯불장어  민물장어 요리 전문식당      인천광역시 강화군 길상면 초지리 1251-573
# 4      4          강화맛집           한식당    길상면 온수리 412-2번지 강화군 인천광역시 KR
# ..   ...           ...           ...                             ...
# 223  282          왕보따리          고기뷔페            인천광역시 남동구 구월동 1458-1
# 224  284        정문숯불구이           음식점          인천광역시 남동구 비류대로762번길 21
# 225  286            맛집           음식점     인천광역시 연수구 청학동 527-23번지 101호
# 226  288         육교추어탕           음식점              인천광역시 남동구 운연동 30-1
# 227  290     인브스키친 구월점      이탈리아 음식점  인천광역시 남동구 구월동 1175-1 구암빌딩 102호
#
#             lat          lng
# 0    37.6282482  126.5325893
# 1    37.6341853  126.5312613
# 2    37.6279993  126.5328668
# ...

# %%
new_review_df = pd.concat([new_review_df, review_df3], ignore_index=True)
new_review_df
# Out:
#      reivewId                                            content  \
# 0           0    생선도 싱싱하고 숯불이 좋아\r\n맛이 좋네요.\r\n메인 생선요리가 따로 나왔는데…
# 1           0  검색해서 간 곳이예요\r\n생선을 숯불에 구우니\r\n이렇게 맛이있구나 3인분을 3명이…
# 2           0  냉동생선이 아니고 생물 생선을 숯불에 구어 고기가 아주 부드럽고 숯불 향이 제대로입...
# 3           0  깔끔함은 바라지않고 맛만보고 간다면 나쁘지않음.\r\n초벌구이한 생선이 나오면  숯...
# 4           0  모듬생선구이₩16.000~계절따라 그때그때 나오는 많이 나오는 생선으로 주시는것같아...
# ..        ...                                                ...
# 651       290                      베이컨 새우볶음밥이 인상적이네요. 하이볼도 좋았구요.
# 652       290  부평점도 좋았지만 구월점은 또 색다르게 따뜻한 분위기의 가게여서 너무 좋았습니다. ...
# 653       290                                 너무 맛있습니다. 적극추천합니다.
# 654       290                    파스타 맛집 인정 .. 사장님을 포함한 모든 분들 왕친절
# 655       290                 음식들 전체적으로 무난하고 직원분들 친절했습니다 조명이 좋네요
#
#                                                  image  star
# 0    https://lh5.googleusercontent.com/p/AF1QipOug3...     4
# 1    https://lh5.googleusercontent.com/p/AF1QipPObL...     5
# ...

# %%
new_id = new_place_df['id'].max() + 1
new_id
# Out:
# 291

# %%
place_df4 = pd.read_csv('/content/drive/MyDrive/모슐랭 프로젝트 데이터 가공/place인천 동구 맛집.csv')
review_df4 = pd.read_csv('/content/drive/MyDrive/모슐랭 프로젝트 데이터 가공/reivew인천 동구 맛집.csv')

# %%
place_df4
# Out:
#      id            name     sub_name                              addr  \
# 0   291            해장국집      해장국 전문점                인천광역시 동구 동산로87번길 6
# 1   292            문화반점       중국 음식점                인천광역시 동구 송림동 233-3
# 2   293             사리원          음식점                  인천광역시 동구 수문통로 62
# 3   294            물레방아          음식점             인천광역시 동구 화수동 화수로 80-1
# 4   295           명동칼국수          한식당                 인천광역시 동구 송현동 67-6
# 5   296           현대물텀벙          음식점                인천광역시 동구 송림동 59-19
# 6   297            만복분식          음식점                인천광역시 동구 송림동 50-20
# 7   298          진천토종순대          한식당           인천광역시 동구 송림3.5동 102-129
# 8   299           수문통짬뽕       중국 음식점           인천광역시 동구 송현1.2동 수문통로 41
# 9   300     우순임원조할머니쭈꾸미  해산물 요리 전문식당                인천광역시 동구 만석동 54-18
# 10  301          송림기사식당          음식점           인천광역시 동구 송림3.5동 새천년로 28
# 11  302            창석주점          음식점                   인천광역시 동구 송림동 55
# ...

# %%
review_df4
# Out:
#      reivewId                                            content  \
# 0         291  이집은 도대체  뭔가요\r\n시설도 써비스도  맛도 아님.  설농탕믜 내용물들도 완...
# 1         291                            1. 양\r\n남자가 먹기는 조금 적은편…
# 2         291          처음엔 음 뭐지 했는데 먹다 보니 싹 비웠네요\r\n해장국 든든한 한 끼.
# 3         291  해장국집! 전부터 한번 와보고 싶었는데 시간이 안 맞아서 이제야 방문을 하게되었습니...
# 4         291  저는 개인적으로 뜨겁게 국밥을 먹는 스타일인데 뜨겁지않아서 금방 식더라고요  그래서...
# ..        ...                                                ...
# 172       342  저희가 이렇게 올린 리뷰로 가게 하나하나를 실시간으로 보듯이 여기 진주만두도 실시간...
# 173       342                                             여기맛있어요
# 174       342                                                몰라요
# 175       342                                                몰라요
# 176       342                                                몰라요
#
#                                                  image  star
# 0    https://lh5.googleusercontent.com/p/AF1QipMvCR...     1
# 1    https://lh5.googleusercontent.com/p/AF1QipMr5H...     5
# ...

# %%
place_df4['id'] += new_id
review_df4['reivewId'] += new_id

# %%
new_place_df = pd.concat([new_place_df, place_df4], ignore_index=True)
new_place_df
# Out:
#       id          name      sub_name                          addr  \
# 0      0  강화도맛집 숯불생선구이       생선 레스토랑       인천광역시 강화군 길상면 해안동로 14-6
# 1      1         등나무가든           음식점       인천광역시 강화군 길상면 초지리 622-1
# 2      2        등대숯불장어           음식점         인천광역시 강화군 길상면 초지로 142
# 3      3       강나루숯불장어  민물장어 요리 전문식당    인천광역시 강화군 길상면 초지리 1251-573
# 4      4          강화맛집           한식당  길상면 온수리 412-2번지 강화군 인천광역시 KR
# ..   ...           ...           ...                           ...
# 261  336       마마손 이야기           음식점   2층, 45 수문통로 송현1.2동 동구 인천광역시
# 262  338          은혜반점           음식점                인천광역시 동구 석수로 5
# 263  340          신라반점        중국 음식점             인천광역시 동구 금곡동 33-6
# 264  342          진주만두           음식점               인천광역시 동구 송림동 50
# 265  344         토마토식당           한식당             인천광역시 동구 송현3동 129
#
#             lat          lng
# 0    37.6282482  126.5325893
# 1    37.6341853  126.5312613
# 2    37.6279993  126.5328668
# 3    37.6206539  126.533254!
# ...

# %%
new_review_df = pd.concat([new_review_df, review_df4], ignore_index=True)
new_review_df
# Out:
#      reivewId                                            content  \
# 0           0    생선도 싱싱하고 숯불이 좋아\r\n맛이 좋네요.\r\n메인 생선요리가 따로 나왔는데…
# 1           0  검색해서 간 곳이예요\r\n생선을 숯불에 구우니\r\n이렇게 맛이있구나 3인분을 3명이…
# 2           0  냉동생선이 아니고 생물 생선을 숯불에 구어 고기가 아주 부드럽고 숯불 향이 제대로입...
# 3           0  깔끔함은 바라지않고 맛만보고 간다면 나쁘지않음.\r\n초벌구이한 생선이 나오면  숯...
# 4           0  모듬생선구이₩16.000~계절따라 그때그때 나오는 많이 나오는 생선으로 주시는것같아...
# ..        ...                                                ...
# 828       342  저희가 이렇게 올린 리뷰로 가게 하나하나를 실시간으로 보듯이 여기 진주만두도 실시간...
# 829       342                                             여기맛있어요
# 830       342                                                몰라요
# 831       342                                                몰라요
# 832       342                                                몰라요
#
#                                                  image  star
# 0    https://lh5.googleusercontent.com/p/AF1QipOug3...     4
# 1    https://lh5.googleusercontent.com/p/AF1QipPObL...     5
# ...

# %%
new_id = new_place_df['id'].max() + 1
new_id
# Out:
# 345

# %%
place_df5 = pd.read_csv('/content/drive/MyDrive/모슐랭 프로젝트 데이터 가공/place인천 미추홀구 맛집.csv')
review_df5 = pd.read_csv('/content/drive/MyDrive/모슐랭 프로젝트 데이터 가공/reivew인천 미추홀구 맛집.csv')

# %%
place_df5
# Out:
#      id        name  sub_name                      addr         lat  \
# 0   345     변가네옹진냉면       한식당     인천광역시 미추홀구 주안동 509-13  37.4576033
# 1   346        청실홍실       음식점     인천광역시 미추홀구 주안1동 190-8  37.4596212
# 2   347   오목골즉석메밀우동       음식점       인천광역시 미추홀구 숭의동 88-1  37.4683896
# 3   348        풍전식당       음식점          인천광역시 미추홀구 남주길 5  37.4545603
# 4   349          화룽       한식당    인천광역시 미추홀구 주안1동 157-17  37.461348!
# ..  ...         ...       ...                       ...         ...
# 66  456    무한조개구이따조  조개구이 전문점         인천광역시 미추홀구 주안로 89  37.4642821
# 67  458     라멘야 삼미당    일본 음식점  인천광역시 미추홀구 용현1.4동 191-91  37.4514062
# 68  460  엄청난회집[숭의동]       음식점            인천광역시 미추홀구 숭의동  37.459299!
# 69  462       부영선지국       음식점                     인천광역시  37.4585144
# 70  464       은비네맛집       음식점    인천광역시 미추홀구 용현동 437 2번지  37.4537359
#
#             lng
# 0   126.6770969
# 1   126.6798069
# 2   126.650851!
# 3   126.6696009
# 4   126.6814181
# ..          ...
# 66  126.6792978
# ...

# %%
review_df5
# Out:
#      reivewId                                            content  \
# 0         345  갈때마다 너무 맛있어요. 인생냉면집. 액젓, 식초, 겨자도 제공되지만 기본 육수가 ...
# 1         345             면발이 아주 맛있는 집!\r\n메밀함량 너무 좋다\r\n다만!!!!…
# 2         345  인천 지하철 2호선 시민회관역에서 가깝다.\r\n주차는 식당 주차장도 있지만 공간이...
# 3         345  김구라맛집?!\r\n\r\n녹두전은 겉바속촉이 느껴지는 고소함이 좋았다 양은 손바닥...
# 4         345  오랜만에 3.1절 휴일이라 인천 맛집 탐방했는데요.\r\n포레스팅아웃팅스 근처 부용...
# ..        ...                                                ...
# 310       462  1982년에 개업한 부영선지국. 개업한지 만 40년이 된 식당입니다. 부영선지국은 ...
# 311       462  겨울을 재촉하는 비가 부슬부슬 내리는날 생각나서 방문했어요. 뛰어난 맛은 아니지만 ...
# 312       462  msg향 안나는 깔끔한 맛. 신선한 선지. 각종부속 충분히 많이 줍니다. 주차는 어...
# 313       462  인천광역시 미추홀구 숭의2동에 위치한 부영선지국에서 소양선지국(7천원)을 먹었습니다...
# 314       462  선지국집인데 맛있습니다  늘먹던 양평해장국과는 다른 맛으로 선지 냄새 없고 양에도 ...
#
#                                                  image  star
# 0    https://lh5.googleusercontent.com/p/AF1QipPpAy...     5
# 1    https://lh5.googleusercontent.com/p/AF1QipOoN1...     2
# ...

# %%
place_df5['id'] += new_id
review_df5['reivewId'] += new_id

# %%
new_place_df = pd.concat([new_place_df, place_df5], ignore_index=True)
new_place_df
# Out:
#       id          name      sub_name                          addr  \
# 0      0  강화도맛집 숯불생선구이       생선 레스토랑       인천광역시 강화군 길상면 해안동로 14-6
# 1      1         등나무가든           음식점       인천광역시 강화군 길상면 초지리 622-1
# 2      2        등대숯불장어           음식점         인천광역시 강화군 길상면 초지로 142
# 3      3       강나루숯불장어  민물장어 요리 전문식당    인천광역시 강화군 길상면 초지리 1251-573
# 4      4          강화맛집           한식당  길상면 온수리 412-2번지 강화군 인천광역시 KR
# ..   ...           ...           ...                           ...
# 332  456      무한조개구이따조      조개구이 전문점             인천광역시 미추홀구 주안로 89
# 333  458       라멘야 삼미당        일본 음식점      인천광역시 미추홀구 용현1.4동 191-91
# 334  460    엄청난회집[숭의동]           음식점                인천광역시 미추홀구 숭의동
# 335  462         부영선지국           음식점                         인천광역시
# 336  464         은비네맛집           음식점        인천광역시 미추홀구 용현동 437 2번지
#
#             lat          lng
# 0    37.6282482  126.5325893
# 1    37.6341853  126.5312613
# 2    37.6279993  126.5328668
# 3    37.6206539  126.533254!
# ...

# %%
new_review_df = pd.concat([new_review_df, review_df5], ignore_index=True)
new_review_df
# Out:
#       reivewId                                            content  \
# 0            0    생선도 싱싱하고 숯불이 좋아\r\n맛이 좋네요.\r\n메인 생선요리가 따로 나왔는데…
# 1            0  검색해서 간 곳이예요\r\n생선을 숯불에 구우니\r\n이렇게 맛이있구나 3인분을 3명이…
# 2            0  냉동생선이 아니고 생물 생선을 숯불에 구어 고기가 아주 부드럽고 숯불 향이 제대로입...
# 3            0  깔끔함은 바라지않고 맛만보고 간다면 나쁘지않음.\r\n초벌구이한 생선이 나오면  숯...
# 4            0  모듬생선구이₩16.000~계절따라 그때그때 나오는 많이 나오는 생선으로 주시는것같아...
# ...        ...                                                ...
# 1143       462  1982년에 개업한 부영선지국. 개업한지 만 40년이 된 식당입니다. 부영선지국은 ...
# 1144       462  겨울을 재촉하는 비가 부슬부슬 내리는날 생각나서 방문했어요. 뛰어난 맛은 아니지만 ...
# 1145       462  msg향 안나는 깔끔한 맛. 신선한 선지. 각종부속 충분히 많이 줍니다. 주차는 어...
# 1146       462  인천광역시 미추홀구 숭의2동에 위치한 부영선지국에서 소양선지국(7천원)을 먹었습니다...
# 1147       462  선지국집인데 맛있습니다  늘먹던 양평해장국과는 다른 맛으로 선지 냄새 없고 양에도 ...
#
#                                                   image  star
# 0     https://lh5.googleusercontent.com/p/AF1QipOug3...     4
# ...

# %%
new_id = new_place_df['id'].max() + 1
new_id
# Out:
# 465

# %%
place_df6 = pd.read_csv('/content/drive/MyDrive/모슐랭 프로젝트 데이터 가공/place인천 부평구 맛집.csv')
review_df6 = pd.read_csv('/content/drive/MyDrive/모슐랭 프로젝트 데이터 가공/reivew인천 부평구 맛집.csv')

# %%
place_df6
# Out:
#      id          name     sub_name                             addr  \
# 0     0  모녀떡볶이 부평남부역점          음식점             인천광역시 부평구 부평동 광장로 16
# 1     1       오구당당 본점          한식당  인천광역시 부평구 부평1동 경원대로1377번길 47 1층
# 2     2          대왕김밥        간이음식점            인천광역시 부평구 부평1동 542-76
# 3     3            에픽          음식점             인천광역시 부평구 부평동 341-30
# 4     4         더히든키친          음식점     인천광역시 부평구 부평동 신트리로22번길 15-14
# ..  ...           ...          ...                              ...
# 65  110           쭈대장          음식점            인천광역시 부평구 부평5동 194-19
# 66  112     권가제면소 부평점       우동 전문점                  인천광역시 부평동 203-9
# 67  114          부평수산        회 전문점             인천광역시 부평구 부평1동 529-5
# 68  116    무한버섯나라 부평점     샤브샤브 전문점     인천광역시 부평구 부평1동 경원대로1377번길 47
# 69  118          대왕포차  해산물 요리 전문식당        인천광역시 부평구 부평4동 부흥북로5번길 18
#
#            lat          lng
# 0   37.4890195  126.7234865
# 1   37.4934427  126.7220378
# 2   37.4941085  126.7218118
# 3   37.491552!  126.7205301
# ...

# %%
review_df6
# Out:
#      reivewId                                            content  \
# 0           0  참 오랜만에 찾은 모녀떡볶이집..\r\n맛은 여전하고 그대로네요..\r\n떡볶이에 ...
# 1           0  맛집이지만 체계가 없어 먹기 힘든 분식집\r\n\r\n음식: 떡볶이는 옛날 그맛. ...
# 2           0  부평에서 맛집...테이블에서 먹기는 힘들고 포장해서 먹어야 시간 절약이 됨..10년...
# 3           0    떡볶이 튀김 정말 맛있어요 12시에 갔는데 순대는 다 떨어졌다고 하셔서 못먹었어요ㅠㅠ
# 4           0  안먹어보면 모르겠지만, 먹어본 사람은 단골될 것 같은 곳입니다. 인천의 유명한 떡볶...
# ..        ...                                                ...
# 343       118  신선한 제철 해산물을 가성비 좋게 먹을수 있는 곳입니다. 해산물과 관련된 회, 샤브...
# 344       118  갈때마다 조개 상태가 항상 신선함👍🏻\r\n바쁜 상황에도 직원분들 모두 친절하시고 ...
# 345       118     도다리와 모듬조개찜 먹었는데 둘 다 구성대비 비싸고 조개찜은 국물이 너무 짜더라구요
# 346       118  정말 맛있고 서비스도 좋은데.. 사장님 조리하실 때 마스크를 신경써서 코까지 올려서...
# 347       118          찜, 구이 둘다 맛있어요 먹는 메뉴들 다 성공!\r\n나만알고싶은 맛집😆…
#
#                                                  image  star
# 0    https://lh5.googleusercontent.com/p/AF1QipOAhP...     4
# 1    https://lh5.googleusercontent.com/p/AF1QipMVRQ...     2
# ...

# %%
place_df6['id'] += new_id
review_df6['reivewId'] += new_id

# %%
new_place_df = pd.concat([new_place_df, place_df6], ignore_index=True)
new_place_df
# Out:
#       id          name      sub_name                          addr  \
# 0      0  강화도맛집 숯불생선구이       생선 레스토랑       인천광역시 강화군 길상면 해안동로 14-6
# 1      1         등나무가든           음식점       인천광역시 강화군 길상면 초지리 622-1
# 2      2        등대숯불장어           음식점         인천광역시 강화군 길상면 초지로 142
# 3      3       강나루숯불장어  민물장어 요리 전문식당    인천광역시 강화군 길상면 초지리 1251-573
# 4      4          강화맛집           한식당  길상면 온수리 412-2번지 강화군 인천광역시 KR
# ..   ...           ...           ...                           ...
# 402  575           쭈대장           음식점         인천광역시 부평구 부평5동 194-19
# 403  577     권가제면소 부평점        우동 전문점               인천광역시 부평동 203-9
# 404  579          부평수산         회 전문점          인천광역시 부평구 부평1동 529-5
# 405  581    무한버섯나라 부평점      샤브샤브 전문점  인천광역시 부평구 부평1동 경원대로1377번길 47
# 406  583          대왕포차   해산물 요리 전문식당     인천광역시 부평구 부평4동 부흥북로5번길 18
#
#             lat          lng
# 0    37.6282482  126.5325893
# 1    37.6341853  126.5312613
# 2    37.6279993  126.5328668
# 3    37.6206539  126.533254!
# ...

# %%
new_review_df = pd.concat([new_review_df, review_df6], ignore_index=True)
new_review_df
# Out:
#       reivewId                                            content  \
# 0            0    생선도 싱싱하고 숯불이 좋아\r\n맛이 좋네요.\r\n메인 생선요리가 따로 나왔는데…
# 1            0  검색해서 간 곳이예요\r\n생선을 숯불에 구우니\r\n이렇게 맛이있구나 3인분을 3명이…
# 2            0  냉동생선이 아니고 생물 생선을 숯불에 구어 고기가 아주 부드럽고 숯불 향이 제대로입...
# 3            0  깔끔함은 바라지않고 맛만보고 간다면 나쁘지않음.\r\n초벌구이한 생선이 나오면  숯...
# 4            0  모듬생선구이₩16.000~계절따라 그때그때 나오는 많이 나오는 생선으로 주시는것같아...
# ...        ...                                                ...
# 1491       583  신선한 제철 해산물을 가성비 좋게 먹을수 있는 곳입니다. 해산물과 관련된 회, 샤브...
# 1492       583  갈때마다 조개 상태가 항상 신선함👍🏻\r\n바쁜 상황에도 직원분들 모두 친절하시고 ...
# 1493       583     도다리와 모듬조개찜 먹었는데 둘 다 구성대비 비싸고 조개찜은 국물이 너무 짜더라구요
# 1494       583  정말 맛있고 서비스도 좋은데.. 사장님 조리하실 때 마스크를 신경써서 코까지 올려서...
# 1495       583          찜, 구이 둘다 맛있어요 먹는 메뉴들 다 성공!\r\n나만알고싶은 맛집😆…
#
#                                                   image  star
# 0     https://lh5.googleusercontent.com/p/AF1QipOug3...     4
# ...

# %%
new_id = new_place_df['id'].max() + 1
new_id
# Out:
# 584

# %%
place_df7 = pd.read_csv('/content/drive/MyDrive/모슐랭 프로젝트 데이터 가공/place인천 서구 맛집.csv')
review_df7 = pd.read_csv('/content/drive/MyDrive/모슐랭 프로젝트 데이터 가공/reivew인천 서구 맛집.csv')

# %%
place_df7['id'] += new_id
review_df7['reivewId'] += new_id

# %%
new_place_df = pd.concat([new_place_df, place_df7], ignore_index=True)
new_place_df
# Out:
#       id          name      sub_name                           addr  \
# 0      0  강화도맛집 숯불생선구이       생선 레스토랑        인천광역시 강화군 길상면 해안동로 14-6
# 1      1         등나무가든           음식점        인천광역시 강화군 길상면 초지리 622-1
# 2      2        등대숯불장어           음식점          인천광역시 강화군 길상면 초지로 142
# 3      3       강나루숯불장어  민물장어 요리 전문식당     인천광역시 강화군 길상면 초지리 1251-573
# 4      4          강화맛집           한식당   길상면 온수리 412-2번지 강화군 인천광역시 KR
# ..   ...           ...           ...                            ...
# 522  699         청라왕아구           음식점             인천광역시 서구 청라동 187-5
# 523  700          청라식당           음식점       연희동 746-14번지 서구 인천광역시 KR
# 524  701          빨간염소           음식점    심곡동 301-10번지 1층 서구 인천광역시 KR
# 525  702        옛날한우국밥           음식점  심곡동 284-1번지 1층 1호 서구 인천광역시 KR
# 526  703     연락골고추장추어탕           음식점                인천광역시 서구 경서로 27
#
#             lat          lng
# 0    37.6282482  126.5325893
# 1    37.6341853  126.5312613
# 2    37.6279993  126.5328668
# 3    37.6206539  126.533254!
# ...

# %%
new_review_df = pd.concat([new_review_df, review_df7], ignore_index=True)
new_review_df
# Out:
#       reivewId                                            content  \
# 0            0    생선도 싱싱하고 숯불이 좋아\r\n맛이 좋네요.\r\n메인 생선요리가 따로 나왔는데…
# 1            0  검색해서 간 곳이예요\r\n생선을 숯불에 구우니\r\n이렇게 맛이있구나 3인분을 3명이…
# 2            0  냉동생선이 아니고 생물 생선을 숯불에 구어 고기가 아주 부드럽고 숯불 향이 제대로입...
# 3            0  깔끔함은 바라지않고 맛만보고 간다면 나쁘지않음.\r\n초벌구이한 생선이 나오면  숯...
# 4            0  모듬생선구이₩16.000~계절따라 그때그때 나오는 많이 나오는 생선으로 주시는것같아...
# ...        ...                                                ...
# 2003       703  오랫만에 고추장 추어탕 먹고왔네요\r\n경서동쪽으로 이전해 오기전부터 다녔던 원조 ...
# 2004       703  고추장추어탕 단일 메뉴이고 주문은 2인 이상!! 1인분에 10000원\r\n반찬으로...
# 2005       703  사장님 부부께서 친절하게 대해주셨어요\r\n조개젓이 맛있네요\r\n추어탕은 조금 짭...
# 2006       703  두부 그다지 싫어하는데 여기두부전은 최고네요! 조개젖깔맛도 최고 반찬다 맛나네요! ...
# 2007       703  지금까지 먹어본 고추장 추어탕중에서 제입맛엔 원탑입니다^^\r\n\r\n조개젓과 두...
#
#                                                   image  star
# 0     https://lh5.googleusercontent.com/p/AF1QipOug3...     4
# ...

# %%
new_id = new_place_df['id'].max() + 1
new_id
# Out:
# 704

# %%
place_df8 = pd.read_csv('/content/drive/MyDrive/모슐랭 프로젝트 데이터 가공/place인천 중구 맛집.csv')
review_df8 = pd.read_csv('/content/drive/MyDrive/모슐랭 프로젝트 데이터 가공/reivew인천 중구 맛집.csv')

# %%
place_df8['id'] += new_id
review_df8['reivewId'] += new_id

# %%
new_place_df = pd.concat([new_place_df, place_df8], ignore_index=True)
new_place_df
# Out:
#       id          name      sub_name                          addr  \
# 0      0  강화도맛집 숯불생선구이       생선 레스토랑       인천광역시 강화군 길상면 해안동로 14-6
# 1      1         등나무가든           음식점       인천광역시 강화군 길상면 초지리 622-1
# 2      2        등대숯불장어           음식점         인천광역시 강화군 길상면 초지로 142
# 3      3       강나루숯불장어  민물장어 요리 전문식당    인천광역시 강화군 길상면 초지리 1251-573
# 4      4          강화맛집           한식당  길상면 온수리 412-2번지 강화군 인천광역시 KR
# ..   ...           ...           ...                           ...
# 566  761       온센텐동 신포      튀김덮밥 전문점           인천광역시 중구 신포로35번길 22
# 567  763        부안기사식당           음식점        인천광역시 중구 항동1가 제물량로 245
# 568  765     제이콥스 핏제리아        피자 전문점             인천광역시 중구 신포동 11-1
# 569  767           삼강옥       설렁탕 전문점          인천광역시 중구 참외전로158번길 1
# 570  769          경남횟집           음식점             인천광역시 중구 신포동 9-16
#
#             lat          lng
# 0    37.6282482  126.5325893
# 1    37.6341853  126.5312613
# 2    37.6279993  126.5328668
# 3    37.6206539  126.533254!
# ...

# %%
new_review_df = pd.concat([new_review_df, review_df8], ignore_index=True)
new_review_df
# Out:
#       reivewId                                            content  \
# 0            0    생선도 싱싱하고 숯불이 좋아\r\n맛이 좋네요.\r\n메인 생선요리가 따로 나왔는데…
# 1            0  검색해서 간 곳이예요\r\n생선을 숯불에 구우니\r\n이렇게 맛이있구나 3인분을 3명이…
# 2            0  냉동생선이 아니고 생물 생선을 숯불에 구어 고기가 아주 부드럽고 숯불 향이 제대로입...
# 3            0  깔끔함은 바라지않고 맛만보고 간다면 나쁘지않음.\r\n초벌구이한 생선이 나오면  숯...
# 4            0  모듬생선구이₩16.000~계절따라 그때그때 나오는 많이 나오는 생선으로 주시는것같아...
# ...        ...                                                ...
# 2218       769  푹푹 찌는 무더위가 반가운 단 하나의 이유는 민어철이 돌아왔기 때문이다. 올해도 작...
# 2219       769  민어와 관련된 다양한 음식을 판매한다.\r\n제철이 아니라서 민어탕을 주문했다.\r...
# 2220       769               민어 잘 한다는 데 어딜 가도 여기 만한 데 없습니다. 확실해요.
# 2221       769                     민어회 맛이 정말 좋았어요\r\n인천가면 또 가야겠어요
# 2222       769  민어 횟집으로 유명하다고 하여 다녀와 봄. 가격이 매우 사악하나 맛집은 분명한듯. ...
#
#                                                   image  star
# 0     https://lh5.googleusercontent.com/p/AF1QipOug3...     4
# ...

# %%
place_df_back = new_place_df.copy()
#review_df_back = new_review_df.copy()

# %%
str.index('!')
# Out:
# 'as'

# %%
def getLocation(loc):
  if loc.find('!') != -1:
    return loc[ : loc.find('!')]
  else :
    return loc

# %%
place_df_back['lat'] = place_df_back['lat'].apply(getLocation)

# %%
place_df_back['lng'] = place_df_back['lng'].apply(getLocation)

# %%
place_df_back.drop(['sub_name'], axis=1, inplace=True)

# %%
place_df_back
# Out:
#       id          name                          addr         lat          lng
# 0      0  강화도맛집 숯불생선구이       인천광역시 강화군 길상면 해안동로 14-6  37.6282482  126.5325893
# 1      1         등나무가든       인천광역시 강화군 길상면 초지리 622-1  37.6341853  126.5312613
# 2      2        등대숯불장어         인천광역시 강화군 길상면 초지로 142  37.6279993  126.5328668
# 3      3       강나루숯불장어    인천광역시 강화군 길상면 초지리 1251-573  37.6206539   126.533254
# 4      4          강화맛집  길상면 온수리 412-2번지 강화군 인천광역시 KR  37.6383857  126.4812836
# ..   ...           ...                           ...         ...          ...
# 566  761       온센텐동 신포           인천광역시 중구 신포로35번길 22  37.4726447  126.6247588
# 567  763        부안기사식당        인천광역시 중구 항동1가 제물량로 245  37.4735955  126.6178226
# 568  765     제이콥스 핏제리아             인천광역시 중구 신포동 11-1  37.4711412  126.6264351
# 569  767           삼강옥          인천광역시 중구 참외전로158번길 1  37.4730284   126.634066
# 570  769          경남횟집             인천광역시 중구 신포동 9-16  37.4713183  126.6267496
#
# [571 rows x 5 columns]

# %%
place_df_back.to_csv('/content/drive/MyDrive/모슐랭 프로젝트 데이터 가공/가계 정보 가공 완료.csv')

# %%
review_df_back.rename(columns = {'reivewId' : 'reviewId'}, inplace = True)

# %%
userId = pd.Series(np.random.randint(50, size=2223))
userId
# Out:
# 0       35
# 1       14
# 2        3
# 3        2
# 4       47
#         ..
# 2218    18
# 2219    13
# 2220    47
# 2221     9
# 2222    26
# Length: 2223, dtype: int64

# %%
review_df_back['userId'] = userId

# %%
review_df_back['content']
# Out:
# 0         생선도 싱싱하고 숯불이 좋아\r\n맛이 좋네요.\r\n메인 생선요리가 따로 나왔는데…
# 1       검색해서 간 곳이예요\r\n생선을 숯불에 구우니\r\n이렇게 맛이있구나 3인분을 3명이…
# 2       냉동생선이 아니고 생물 생선을 숯불에 구어 고기가 아주 부드럽고 숯불 향이 제대로입...
# 3       깔끔함은 바라지않고 맛만보고 간다면 나쁘지않음.\r\n초벌구이한 생선이 나오면  숯...
# 4       모듬생선구이₩16.000~계절따라 그때그때 나오는 많이 나오는 생선으로 주시는것같아...
#                               ...
# 2218    푹푹 찌는 무더위가 반가운 단 하나의 이유는 민어철이 돌아왔기 때문이다. 올해도 작...
# 2219    민어와 관련된 다양한 음식을 판매한다.\r\n제철이 아니라서 민어탕을 주문했다.\r...
# 2220                 민어 잘 한다는 데 어딜 가도 여기 만한 데 없습니다. 확실해요.
# 2221                       민어회 맛이 정말 좋았어요\r\n인천가면 또 가야겠어요
# 2222    민어 횟집으로 유명하다고 하여 다녀와 봄. 가격이 매우 사악하나 맛집은 분명한듯. ...
# Name: content, Length: 2223, dtype: object

# %%
from random import *
from datetime import date, timedelta
import calendar
import string

def randomKoreanFirstName(size : int):
    nm_idx = ''.join(['가각간갈감갑강개객갱갹거건걸검겁게격견결겸경계고곡곤골공곶과곽관괄광괘괴괵굉교구국군굴궁권궐궤귀규균귤극근글금급긍기긴길김끽나낙난날남납낭내녀녁년념녑녕노농뇌뇨누눈눌뉴뉵능니닉닐다단달담답당대댁덕도독돈돌동두둔둘득등라락란랄람랍랑래랭'
              ,'략량려력련렬렴렵령례로록론롱뢰료룡루류륙륜률륭륵름릉리린림립마막만말망매맥맹멱면멸명몌모목몰몽묘무묵문물미민밀박반발방배백번벌범법벽변별병보복본볼봉부북분불붕비빈빙사삭산살삼삽상새색생서석선설섬섭성세소속손솔송쇄쇠수숙순술숭쉬슬습승시'
              ,'식신실심십쌍씨아악안알암압앙애액앵야약양어억언얼엄업에엔여역연열염엽영예오옥온올옹와완왈왕왜외요욕용우욱운울웅원월위유육윤율융은을음읍응의이익인일임입잉자작잔잠잡장재쟁저적전절점접정제조족존졸종좌죄주죽준줄중즉즐즙증지직진질짐집징차착'
              ,'찬찰참창채책처척천철첨첩청체초촉촌총촬최추축춘출충췌취측층치칙친칠침칩칭쾌타탁탄탈탐탑탕태택탱터토톤통퇴투퉁특틈파판팔패팽퍅편폄평폐포폭표품풍피픽필핍하학한할함합항해핵행향허헌헐험혁현혈혐협형혜호혹혼홀홍화확환활황회획횡효후훈훌훙훤훼휘휴휼흉흑흔흘흠흡흥희히힐'])
    return ''.join(choice(nm_idx) for _ in range(size))

def randomKoreanLastName(size : int):
    lst_nm_idx = '김이박최정강조윤장임한오서신권황안송류전홍고문양손배백허유남심지노하곽성차주우구라민진엄채원천방공현함변염여추도소석선설마길연위표명기반왕금옥육인맹제모탁국어은편용예경봉사부가복태목형계피두감음빈동온호범좌팽승간상시갈단견당화창'
    return ''.join(choice(lst_nm_idx) for _ in range(size))

def randomKoreanFullName(last_name_size = 1, first_name_size = 2):
    return ''.join([randomKoreanLastName(randint(1, last_name_size)), randomKoreanFirstName(first_name_size)])

# %%
emails = ['@naver.com', '@kakao.com', '@gmail.com', '@github.com']
def randomEmail():
    srting_pool = string.ascii_letters
    return ''.join(choice(srting_pool) for _ in range(12)) + choice(emails)

# %%
def randomNumric(size : int):
    string_pool = string.digits
    return ''.join(choice(string_pool) for _ in range(size))

# %%
users = []
for i in range(50):
  users.append([randomEmail(), randomKoreanFullName(), randomKoreanFullName(4, 3), randomNumric(10)])

# %%
pip install passlib psycopg2-binary
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 525.6/525.6 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 24.3 MB/s eta 0:00:00
# ...

# %%
from passlib.hash import pbkdf2_sha256

# %%
def create_hash_passwrod(new_password):
    hash_password = pbkdf2_sha256.hash(new_password + 'moschelin20230815')
    return hash_password

# %%
user_df = pd.DataFrame(data=users, columns=['email', 'name', 'nickname', 'password'])
user_df

# %%
user_df['hash_password'] = user_df['password'].apply(lambda x : create_hash_passwrod(x))

# %%
user_df.to_csv('/content/drive/MyDrive/모슐랭 프로젝트 데이터 가공/테스트 유저 생성 완료.csv')

# %%
review_df_back.index
# Out:
# RangeIndex(start=0, stop=2223, step=1)

# %%
review_photo_df = review_df_back['image'].to_frame().rename(columns={'image' : 'photoURL'})
review_photo_df
# Out:
#                                                photoURL
# 0     https://lh5.googleusercontent.com/p/AF1QipOug3...
# 1     https://lh5.googleusercontent.com/p/AF1QipPObL...
# 2     https://lh5.googleusercontent.com/p/AF1QipPObL...
# 3     https://lh5.googleusercontent.com/p/AF1QipM-3N...
# 4     https://lh5.googleusercontent.com/p/AF1QipON55...
# ...                                                 ...
# 2218  https://lh5.googleusercontent.com/p/AF1QipMTax...
# 2219  https://lh5.googleusercontent.com/p/AF1QipPXC6...
# 2220  https://lh5.googleusercontent.com/p/AF1QipO5bd...
# 2221  https://lh5.googleusercontent.com/p/AF1QipPw3y...
# 2222  https://lh5.googleusercontent.com/p/AF1QipMLCP...
#
# [2223 rows x 1 columns]

# %%
review_photo_df.to_csv('/content/drive/MyDrive/모슐랭 프로젝트 데이터 가공/리뷰 게시물 사진 가공 완료.csv')

# %%
review_photo_df.count
# Out:
# <bound method DataFrame.count of                                                photoURL
# 0     https://lh5.googleusercontent.com/p/AF1QipOug3...
# 1     https://lh5.googleusercontent.com/p/AF1QipPObL...
# 2     https://lh5.googleusercontent.com/p/AF1QipPObL...
# 3     https://lh5.googleusercontent.com/p/AF1QipM-3N...
# 4     https://lh5.googleusercontent.com/p/AF1QipON55...
# ...                                                 ...
# 2218  https://lh5.googleusercontent.com/p/AF1QipMTax...
# 2219  https://lh5.googleusercontent.com/p/AF1QipPXC6...
# 2220  https://lh5.googleusercontent.com/p/AF1QipO5bd...
# 2221  https://lh5.googleusercontent.com/p/AF1QipPw3y...
# 2222  https://lh5.googleusercontent.com/p/AF1QipMLCP...
#
# [2223 rows x 1 columns]>

# %%
review_df_back = review_df_back.rename(columns={'reviewId' : 'storeId'}).drop('image', axis=1)

# %%
review_df_back.to_csv('/content/drive/MyDrive/모슐랭 프로젝트 데이터 가공/리뷰 게시물 가공 완료.csv')

# %%
comment_list = [
"이 음식은 정말 신선한 재료로 만들어져서 맛이 더욱 풍부했어요.",
"매번 먹을 때마다 다른 맛을 느낄 수 있는 음식이었습니다. 정말 흥미로웠어요.",
"이 음식의 향긋한 향과 함께 입안 가득 퍼지는 맛이 정말 환상적이었어요.",
"다양한 조합의 재료가 적절하게 섞여 있는 음식이었습니다. 맛의 깊이를 느낄 수 있었어요.",
"이 음식은 정말 가볍고 건강한 느낌을 주었어요. 식사 후에도 느끼지 않아서 좋았습니다.",

"매우 특별한 음식으로, 이런 맛을 처음 느껴보았어요. 정말 인상 깊었습니다.",

"이 음식은 놀라울 정도로 밸런스가 잘 맞았어요. 각각의 맛이 서로를 존중하며 조화롭게 어우러졌습니다.",

"이 음식은 고요한 맛과 함께 정서적인 만족감을 선사해주었습니다.",

"먹을 때마다 새로운 맛을 발견할 수 있는 음식으로, 먹는 즐거움이 두 배였어요.",

"이 음식은 정말 독특한 풍미를 가지고 있어서, 예상치 못한 즐거움을 주었습니다.",

"입안에서 퍼지는 풍부한 맛이 오래 기억에 남을 것 같아요.",

"이 음식은 진정한 고급 레스토랑의 맛을 집에서 느낄 수 있게 해주었습니다.",

"매우 신선한 재료로 만들어진 음식이어서 건강한 식사를 할 수 있었어요.",

"이 음식은 정말 특별한 기념일에 어울릴 것 같아요. 감동을 주었습니다.",

"매우 정교한 조리법으로 만들어져서 입맛을 사로잡았어요.",

"이 음식을 먹으면서 시간 가는 줄 몰랐어요. 그만큼 맛있었습니다.",

"특별한 소스와 함께하는 이 음식은 정말 독특한 풍미를 가졌어요.",

"이 음식은 정말 산뜻한 느낌을 주었어요. 식사 후에 기분이 좋아졌습니다.",

"입안에서 확장되는 향과 맛이 정말 인상적이었어요.",

"맛있는 음식을 먹으면서 좋은 시간을 보냈어요. 정말 만족스러웠습니다.",

"맛있는 음식을 먹으면서 가족과 함께한 시간을 더욱 소중하게 느꼈어요.",

"이 음식은 정말 개성 있는 맛을 가졌어요. 맛의 다양성이 인상 깊었습니다.",

"이 음식은 정말 특별한 재료로 만들어져서 먹는 재미가 두 배였어요.",

"입안에서 녹아내리는 듯한 부드러움과 맛이 정말 환상적이었어요.",

"이 음식은 정말 독특한 조합으로 만들어져서 맛에 대한 새로운 시선을 얻게 해주었어요.",

"각각의 맛이 조화롭게 어우러진 이 음식은 정말 풍성한 식사였어요.",

"맛있는 음식을 먹으면서 행복한 느낌을 받았어요. 정말 감사한 시간이었습니다.",

"이 음식은 정말 기분을 업시켜주었어요. 맛과 향이 정말 좋았습니다.",

"맛있는 음식을 먹으면서 웃음이 나왔어요. 정말 유쾌한 식사였습니다.",

"이 음식은 정말 특별한 날의 기분을 느낄 수 있게 해주었습니다.",
"이 음식은 정말 특별한 맛으로, 일상에서 벗어나는 느낌을 주었습니다.",

"입안 가득 퍼지는 풍부한 맛과 함께, 정말로 맛있는 식사였어요.",

"이 음식의 신선한 재료들이 정말 인상적이었어요. 맛이 실로 다르게 느껴졌습니다.",

"매우 고급스러운 음식으로, 세련된 조합이 정말 멋졌어요.",

"이 음식을 먹으면서 즉각적으로 기분이 좋아지는 것을 느낄 수 있었어요.",

"양도 푸짐하고 맛도 정말 훌륭한 음식이었습니다. 배부르게 먹었어요.",

"이 음식은 정말 가볍고 상큼한 느낌을 주어서, 먹은 후에도 가벼웠어요.",

"맛과 향이 정말 조화로워서, 여러 가지 감각을 함께 느낄 수 있었어요.",

"이 음식은 특별한 토핑과 함께 완성되어서 정말 맛있게 먹었어요.",

"입안에서 퍼지는 감미로운 맛이 먹는 동안 기분 좋은 시간을 만들어 주었습니다.",

"이 음식은 정말 독특한 맛을 가지고 있어서, 먹는 동안 계속 흥미로웠어요.",

"매우 정교한 조리법으로 만들어져서, 이런 맛은 처음 경험이었어요.",

"이 음식을 먹으면서 어린 시절의 추억이 떠올랐어요. 정말 따뜻한 느낌이었습니다.",

"각각의 재료가 세심하게 조합되어서, 이 음식의 맛은 확실히 다릅니다.",

"입안에서 펼쳐지는 풍부한 향과 함께, 정말 맛있는 식사였어요.",

"이 음식은 정말 신선한 맛으로, 먹을 때마다 새로운 느낌을 주었습니다.",

"맛있는 음식을 먹으면서 행복한 기분이 찾아왔어요. 정말 기분 좋은 식사였습니다.",

"이 음식의 특별한 풍미와 함께, 먹는 즐거움이 배가 되었어요.",

"정말로 독특한 음식으로, 맛있는 경험을 더욱 풍부하게 해주었습니다.",

"이 음식은 정말로 맛과 미가 조화로워, 감탄할 수밖에 없었어요.",

"맛있는 음식을 먹으면서 친구들과 함께한 시간이 더욱 특별했어요.",

"이 음식은 정말 특별한 소스와 함께 제공되어서, 맛이 더욱 독특했습니다.",

"입안 가득 느껴지는 감미로운 향과 함께, 정말 환상적인 식사였어요.",

"이 음식을 먹으면서 진정한 맛의 다양성을 느낄 수 있었어요.",

"정말로 고급스러운 음식으로, 맛과 향이 놀라울 정도로 좋았어요.",

"이 음식은 정말 가볍고 상큼한 느낌을 주어서, 식사 후에도 기분 좋았어요.",

"입안에서 확장되는 향과 함께, 이 음식의 신비로움을 느낄 수 있었어요.",

"맛있는 음식을 먹으면서 다양한 감정을 함께 느꼈어요. 정말 특별한 식사였습니다.",

"이 음식은 정말로 신선한 재료로 만들어져서, 맛의 깊이가 느껴졌어요.",

"입안에서 퍼지는 화려한 맛과 함께, 정말 감동적인 식사였어요.",
"이 음식은 정말로 입맛을 만족시켜 주는 맛이었어요. 맛있게 먹었습니다.",

"다양한 맛이 조화롭게 어우러져서, 이 음식의 특별함을 느낄 수 있었어요.",

"이 음식을 먹으면서 활력이 찾아왔어요. 정말 기분 좋은 식사였습니다.",

"입안에서 확장되는 감미로운 맛과 함께, 정말로 맛있게 먹었습니다.",

"이 음식은 정말 신선한 재료로 만들어져서, 정말로 신선한 맛을 느낄 수 있었습니다.",

"맛있는 음식을 먹으면서 정말로 기분이 좋아지는 느낌을 받았어요.",

"이 음식은 정말로 세련된 조합으로, 입맛을 매우 만족시켜 주었습니다.",

"입안에서 펼쳐지는 감미로운 향과 함께, 정말로 맛있는 식사였어요.",

"이 음식은 정말 독특한 맛을 가지고 있어서, 식사를 더욱 흥미롭게 만들어 주었습니다.",

"맛과 향이 정말로 조화롭게 어우러져, 이 음식을 먹는 즐거움이 배가 되었어요.",

"이 음식은 정말 특별한 소스와 함께 제공되어서, 먹는 즐거움이 배가 되었습니다.",

"입안에서 확장되는 환상적인 맛과 함께, 정말 감탄스러운 식사였어요.",

"이 음식을 먹으면서 즉각적으로 기분이 좋아지는 것을 느낄 수 있었어요.",

"맛과 향이 정말 조화롭게 어우러져, 이 음식의 신비로움을 느낄 수 있었습니다.",

"이 음식은 정말로 맛의 다양성을 느낄 수 있는 특별한 조합이었습니다.",

"입안에서 확장되는 감미로운 향과 함께, 정말로 맛있게 먹었습니다.",

"이 음식은 정말 신선한 재료로 만들어져서, 정말로 신선한 맛을 느낄 수 있었습니다.",

"맛있는 음식을 먹으면서 정말로 기분이 좋아지는 느낌을 받았어요.",

"이 음식은 정말로 세련된 조합으로, 입맛을 매우 만족시켜 주었습니다.",

"입안에서 펼쳐지는 감미로운 향과 함께, 정말로 맛있는 식사였어요.",

"이 음식은 정말 독특한 맛을 가지고 있어서, 식사를 더욱 흥미롭게 만들어 주었습니다.",

"맛과 향이 정말로 조화롭게 어우러져, 이 음식을 먹는 즐거움이 배가 되었어요.",

"이 음식은 정말 특별한 소스와 함께 제공되어서, 먹는 즐거움이 배가 되었습니다.",

"입안에서 확장되는 환상적인 맛과 함께, 정말 감탄스러운 식사였어요.",

"이 음식을 먹으면서 즉각적으로 기분이 좋아지는 것을 느낄 수 있었어요.",

"맛과 향이 정말 조화롭게 어우러져, 이 음식의 신비로움을 느낄 수 있었습니다.",

"이 음식은 정말로 맛의 다양성을 느낄 수 있는 특별한 조합이었습니다.",

"입안에서 확장되는 감미로운 향과 함께, 정말로 맛있게 먹었습니다.",

"이 음식은 정말 신선한 재료로 만들어져서, 정말로 신선한 맛을 느낄 수 있었습니다.",

"맛있는 음식을 먹으면서 정말로 기분이 좋아지는 느낌을 받았어요.",

"이 음식은 정말로 세련된 조합으로, 입맛을 매우 만족시켜 주었습니다.",

"입안에서 펼쳐지는 감미로운 향과 함께, 정말로 맛있는 식사였어요.",

"이 음식은 정말 독특한 맛을 가지고 있어서, 식사를 더욱 흥미롭게 만들어 주었습니다.",

"맛과 향이 정말로 조화롭게 어우러져, 이 음식을 먹는 즐거움이 배가 되었어요.",

"이 음식은 정말 특별한 소스와 함께 제공되어서, 먹는 즐거움이 배가 되었습니다.",

"입안에서 확장되는 환상적인 맛과 함께, 정말 감탄스러운 식사였어요.",

"이 음식을 먹으면서 즉각적으로 기분이 좋아지는 것을 느낄 수 있었어요.",

"맛과 향이 정말 조화롭게 어우러져, 이 음식의 신비로움을 느낄 수 있었습니다.",
"이 음식은 정말로 맛의 다양성을 느낄 수 있는 특별한 조합이었습니다.",
"입안에서 확장되는 감미로운 향과 함께, 정말로 맛있게 먹었습니다."]

# %%
def rand_review_comment_create():
  return choice(comment_list)

# %%
randint(0, 2222)
# Out:
# 1283

# %%
comments = []
for i in range(10000):
  comments.append([randint(0, 49), randint(0, 2222), rand_review_comment_create()])

# %%
review_comments = pd.DataFrame(data=comments, columns=['userId', 'reviewId', 'content'])
# Out:
#       userId  reviewId                                          content
# 0          8       637  이 음식은 정말 독특한 맛을 가지고 있어서, 식사를 더욱 흥미롭게 만들어 주었습니다.
# 1         48       989             매우 정교한 조리법으로 만들어져서, 이런 맛은 처음 경험이었어요.
# 2         19       983                   매우 정교한 조리법으로 만들어져서 입맛을 사로잡았어요.
# 3         46      2164          이 음식을 먹으면서 즉각적으로 기분이 좋아지는 것을 느낄 수 있었어요.
# 4         40      1955              맛있는 음식을 먹으면서 정말로 기분이 좋아지는 느낌을 받았어요.
# ...      ...       ...                                              ...
# 9995       6       191         이 음식은 정말 산뜻한 느낌을 주었어요. 식사 후에 기분이 좋아졌습니다.
# 9996      20      1299   이 음식은 정말 신선한 재료로 만들어져서, 정말로 신선한 맛을 느낄 수 있었습니다.
# 9997       3      1509            입안 가득 느껴지는 감미로운 향과 함께, 정말 환상적인 식사였어요.
# 9998       4      1588                   매우 정교한 조리법으로 만들어져서 입맛을 사로잡았어요.
# 9999      40      1437     먹을 때마다 새로운 맛을 발견할 수 있는 음식으로, 먹는 즐거움이 두 배였어요.
#
# [10000 rows x 3 columns]

# %%
review_comments.to_csv('/content/drive/MyDrive/모슐랭 프로젝트 데이터 가공/리뷰 게시물 댓글 생성 완료.csv')

# %%
likes = []

# %%
for i in range(10000):
  rand_lies = (randint(0, 49), randint(0, 2222))
  if rand_lies not in likes:
    likes.append(rand_lies)

# %%
likes_df = pd.DataFrame(data=likes, columns=['userId', 'reviewId'])
likes_df
# Out:
#        userId  reviewId
# 0          10       100
# 1           8       976
# 2          32        73
# 3          31      1943
# 4          17       627
# ...       ...       ...
# 26293      48      1790
# 26294      45      1251
# 26295       4      2025
# 26296       8      2178
# 26297      49       247
#
# [26298 rows x 2 columns]

# %%
likes_df.to_csv('/content/drive/MyDrive/모슐랭 프로젝트 데이터 가공/리뷰 게시물 좋아요 생성 완료.csv')
