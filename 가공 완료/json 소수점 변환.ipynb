# %%
import json

# %%
with open('C:/Users/Home/Documents/Github/aws_moschelin_project_data_process/가공 완료/store.json', 'w', encoding='utf-8') as make_file:
    json_data = json.load(make_file)
    print(json_data)
    #json.dump(json_data, make_file, indent="\t")

# %%
paths = 'C:/Users/Home/Documents/Github/aws_moschelin_project_data_process/가공 완료/store.json'

# %%
with open(paths, 'r', encoding='UTF-8') as file:
    data = json.load(file)

# %%
for i in range(len(data)):
    data[i]['lat'] = f'{data[i]["lat"]}'
    data[i]['lng'] = f'{data[i]["lng"]}'

# %%
data
# Out:
# [{'id': 0,
#   'id__1': 0,
#   'name': '강화도맛집 숯불생선구이',
#   'addr': '인천광역시 강화군 길상면 해안동로 14-6',
#   'lat': '37.6282482',
#   'lng': '126.5325893'},
#  {'id': 1,
#   'id__1': 1,
#   'name': '등나무가든',
#   'addr': '인천광역시 강화군 길상면 초지리 622-1',
#   'lat': '37.6341853',
#   'lng': '126.5312613'},
#  {'id': 2,
#   'id__1': 2,
#   'name': '등대숯불장어',
#   'addr': '인천광역시 강화군 길상면 초지로 142',
#   'lat': '37.6279993',
#   'lng': '126.5328668'},
#  {'id': 3,
#   'id__1': 3,
#   'name': '강나루숯불장어',
#   'addr': '인천광역시 강화군 길상면 초지리 1251-573',
#   'lat': '37.6206539',
#   'lng': '126.533254'},
#  {'id': 4,
#   'id__1': 4,
#   'name': '강화맛집',
#   'addr': '길상면 온수리 412-2번지 강화군 인천광역시 KR',
#   'lat': '37.6383857',
#   'lng': '126.4812836'},
#  {'id': 5,
#   'id__1': 5,
#   'name': '토가',
#   'addr': '인천광역시 강화군 화도면 흥왕리 566-1',
#   'lat': '37.6084833',
#   'lng': '126.4174884'},
#  {'id': 6,
#   'id__1': 6,
#   'name': '진복호 강화도',
#   'addr': '인천광역시 강화군 길상면 선두리 1069-4',
#   'lat': '37.5974971',
# ...

# %%
with open(paths, 'w', encoding='UTF-8') as outfile:
    json.dump(data, outfile, indent="\t", ensure_ascii=False)
