# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

from time import sleep

# %%
import pandas as pd
import numpy as np
import os

# %%
# 크롬 열기
url = 'https://www.google.co.kr/maps/?hl=ko&entry=ttu'

driver = webdriver.Chrome()
driver.get(url)
keyword = '인천 서구 맛집'

# %%
keyword = f'인천 {서구} 맛집'

# %%
# 검색어 입력
search = driver.find_element(By.NAME, 'q')
search.send_keys(keyword)
search.submit()

# %%
# 검색 시작 버튼 클릭
search_button = driver.find_element(By.CSS_SELECTOR, 'div.pzfvzf')
search_button.click()

# %%
# 스크롤 내리기
scroll_div = driver.find_element(By.XPATH, '//*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]')

# %%
while 1:
    scroll_div.send_keys(Keys.END)
    driver.implicitly_wait(1)
    sleep(1)

    try:
        end_point = driver.find_element(By.XPATH, '//*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[243]/div/p/span/span')

        if end_point.text == '마지막 항목입니다.':
            break
    except:
        pass

# %%
# 위도 경도 가져오기
def get_location():
    current_url = driver.current_url

    lat_url = current_url.find("!3d") + 3
    lng_url = current_url.find("!4d") + 3
    lat = current_url[lat_url : lat_url+10]
    lng = current_url[lng_url : lng_url+11]

    return {'lat' : lat,
            'lng' : lng}

# %%
place_columns = ['name', 'sub_name', 'addr', 'lat', 'lng']
place_df = pd.DataFrame(columns = place_columns)

review_columns = ['reivewId', 'content', 'image', 'star']
review_df = pd.DataFrame(columns = review_columns)

# %%
# 가게 정보 리스트 저장
place_list = driver.find_elements(By.CSS_SELECTOR, 'div.Nv2PK.THOPZb.CpccDe > a.hfpxzc')
sleep(2)

for i in range(11, len(place_list)):
    # 가게 클릭
    try:
        place_list[i].click()
        driver.implicitly_wait(10)
        sleep(2)
    except:
        print('해당 음식점 찾을 수 없음')
        continue

    # 위도 경도 가져오기
    location = get_location()
    
    # 가게 이름
    place_name = driver.find_element(By.XPATH, '//*[@id="QA0Szd"]/div/div/div[1]/div[3]/div/div[1]/div/div/div[2]/div[2]/div/div[1]/div[1]/h1').text
    
    # 가게 부가 정보
    place_sub_name = driver.find_element(By.XPATH, '//*[@id="QA0Szd"]/div/div/div[1]/div[3]/div/div[1]/div/div/div[2]/div[2]/div/div[1]/div[2]/div/div[2]/span/span/button').text

    # 가게 주소
    place_addr = driver.find_element(By.XPATH, '//*[@id="QA0Szd"]/div/div/div[1]/div[3]/div/div[1]/div/div/div[2]/div[9]/div[3]/button/div/div[2]/div[1]').text

    place_sub_df = pd.DataFrame([[place_name, place_sub_name, place_addr, location['lat'], location['lng']]], columns=place_columns)

    place_df = pd.concat([place_df, place_sub_df], ignore_index=True)
    print(f"{i} 번째 가게 등록 --- 완료...")
    sleep(2)
    

    # 리뷰 탭 클릭
    review_button = driver.find_element(By.XPATH, '//*[@id="QA0Szd"]/div/div/div[1]/div[3]/div/div[1]/div/div/div[2]/div[3]/div/div/button[2]')
    review_button.click()
    driver.implicitly_wait(10)
    sleep(2)


    # 리뷰 글 전체
    # 리뷰 글 전체
    review_div = driver.find_elements(By.CSS_SELECTOR, 'div.jftiEf.fontBodyMedium ')[:5]

    for review in review_div:
        # 별점 가져오기
        review_star = review.find_element(By.CSS_SELECTOR, 'span.kvMYJc').accessible_name[-2]

        

        try:
            # 리뷰 글
            review_content = review.find_element(By.CSS_SELECTOR, 'span.wiI7pd')
            review_content_str = '' if review_content == None else review_content.text

            # 이미지 URL
            review_image = review.find_element(By.CSS_SELECTOR, 'div.KtCyie > button')
            url = review_image.get_attribute('style')
            url = url[url.find('https://') : url.find('");')]
        except:
            pass

        reivew_sub_df = pd.DataFrame([[i, review_content_str, url, review_star]], columns=review_columns)

        review_df = pd.concat([review_df, reivew_sub_df], ignore_index=True)
        
    print(f"{place_name} 리뷰 등록 --- 완료...")
    sleep(2)
# Out:
# 11 번째 가게 등록 --- 완료...
# 동남집 리뷰 등록 --- 완료...
# 12 번째 가게 등록 --- 완료...
# 서가네 리뷰 등록 --- 완료...
# 13 번째 가게 등록 --- 완료...
# 정복앤아구 리뷰 등록 --- 완료...
# 14 번째 가게 등록 --- 완료...
# 백령면옥 리뷰 등록 --- 완료...
# 15 번째 가게 등록 --- 완료...
# 원갈비 리뷰 등록 --- 완료...
# 16 번째 가게 등록 --- 완료...
# 국수궁전 리뷰 등록 --- 완료...
# 17 번째 가게 등록 --- 완료...
# 본죽 인천서구청점 리뷰 등록 --- 완료...
# 18 번째 가게 등록 --- 완료...
# 청라수산 리뷰 등록 --- 완료...
# 19 번째 가게 등록 --- 완료...
# 삼대째 손두부 리뷰 등록 --- 완료...
# 20 번째 가게 등록 --- 완료...
# 소안의섬 리뷰 등록 --- 완료...
# 21 번째 가게 등록 --- 완료...
# 대청마루 리뷰 등록 --- 완료...
# 22 번째 가게 등록 --- 완료...
# 본터 리뷰 등록 --- 완료...
# 23 번째 가게 등록 --- 완료...
# 마왕족발 인천서구청점 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 25 번째 가게 등록 --- 완료...
# 이집트 경양식 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 27 번째 가게 등록 --- 완료...
# 해오름나주곰탕 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 29 번째 가게 등록 --- 완료...
# 백년불고기 서구청점 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 31 번째 가게 등록 --- 완료...
# 신전떡볶이 인천서구청점 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 33 번째 가게 등록 --- 완료...
# 백지연식당 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 35 번째 가게 등록 --- 완료...
# 유진족발본점 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 37 번째 가게 등록 --- 완료...
# 청운해물아구전문점 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 39 번째 가게 등록 --- 완료...
# 오자매생선촌 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 41 번째 가게 등록 --- 완료...
# 대학로족발 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 43 번째 가게 등록 --- 완료...
# 미도방만두 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 45 번째 가게 등록 --- 완료...
# 불타는명태조림서구청점 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 47 번째 가게 등록 --- 완료...
# 고창수산 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 49 번째 가게 등록 --- 완료...
# 수원집갈비탕 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 51 번째 가게 등록 --- 완료...
# 집밥집 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 53 번째 가게 등록 --- 완료...
# 연희동함흥냉면 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 55 번째 가게 등록 --- 완료...
# 광화문빈대떡 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 57 번째 가게 등록 --- 완료...
# 삼원부대찌개 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 59 번째 가게 등록 --- 완료...
# 명동보리밥 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 61 번째 가게 등록 --- 완료...
# 돈까스하우스 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 63 번째 가게 등록 --- 완료...
# 성원닭갈비 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 65 번째 가게 등록 --- 완료...
# 월출산흑염소탕추어탕 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 67 번째 가게 등록 --- 완료...
# 안동잔치국수 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 69 번째 가게 등록 --- 완료...
# 구수옥 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 71 번째 가게 등록 --- 완료...
# 낙지한마당 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 73 번째 가게 등록 --- 완료...
# 추오정남원추어탕 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 75 번째 가게 등록 --- 완료...
# 마포식당 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 77 번째 가게 등록 --- 완료...
# 너의샐러드 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 79 번째 가게 등록 --- 완료...
# 유천가든 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 81 번째 가게 등록 --- 완료...
# 제주도야지 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 83 번째 가게 등록 --- 완료...
# 연락골고추장추어탕 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 85 번째 가게 등록 --- 완료...
# 철원양평해장국 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 87 번째 가게 등록 --- 완료...
# 인천 심곡동 염소탕 맛집 가시골염소마을 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 89 번째 가게 등록 --- 완료...
# 콩세알한식 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 91 번째 가게 등록 --- 완료...
# 굴세상 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 93 번째 가게 등록 --- 완료...
# 옛날한우국밥 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 95 번째 가게 등록 --- 완료...
# 이태리공방 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 97 번째 가게 등록 --- 완료...
# 산해관 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 99 번째 가게 등록 --- 완료...
# 공촌주먹고기 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 101 번째 가게 등록 --- 완료...
# 신차이나 포차 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 103 번째 가게 등록 --- 완료...
# 들낙 손칼국수 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 105 번째 가게 등록 --- 완료...
# 금화정남원추어탕 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 107 번째 가게 등록 --- 완료...
# 연희네야채곱창 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 109 번째 가게 등록 --- 완료...
# 명태덕장 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 111 번째 가게 등록 --- 완료...
# 해촌 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 113 번째 가게 등록 --- 완료...
# 아리오돌뼈신닭발 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 115 번째 가게 등록 --- 완료...
# 탑수산 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 117 번째 가게 등록 --- 완료...
# 원조팥죽팥칼국수 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 119 번째 가게 등록 --- 완료...
# 도참치 리뷰 등록 --- 완료...

# %%
place_df.to_csv(f'C:/Users/wjdak/Documents/place{keyword}.csv', index=False, encoding='utf-8-sig')
review_df.to_csv(f'C:/Users/wjdak/Documents/reivew{keyword}.csv', index=False, encoding='utf-8-sig')

# %%
review_df

# %%
# 위도 경도 가져오기
def get_location():
    current_url = driver.current_url

    lat_url = current_url.find("!3d") + 3
    lng_url = current_url.find("!4d") + 3
    lat = current_url[lat_url : lat_url+10]
    lng = current_url[lng_url : lng_url+11]

    return {'lat' : lat,
            'lng' : lng}

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

from time import sleep
import pandas as pd



keyword_list = [
    #'서구',
    #'남동구',
#     '강화군',
# '계양구',
# '동구',
# '미추홀구',
# '부평구',
# '연수구', 몇개안됨
# '옹진군',
'중구',]

for k in keyword_list:

    keyword = f'인천 {k} 맛집'

    # 검색어 입력
    search = driver.find_element(By.NAME, 'q')
    search.clear()
    search.send_keys(keyword)
    search.submit()
    driver.implicitly_wait(10)
    sleep(1)

    # 검색 시작 버튼 클릭
    search_button = driver.find_element(By.CSS_SELECTOR, 'div.pzfvzf')
    search_button.click()
    driver.implicitly_wait(10)
    sleep(5)

    # 스크롤 내리기
    scroll_div = driver.find_element(By.XPATH, '//*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]')
    driver.implicitly_wait(10)
    sleep(2)
    
    while 1:
        scroll_div.send_keys(Keys.END)
        driver.implicitly_wait(1)
        sleep(1)

        try:
            end_point = driver.find_element(By.XPATH, '//*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div[243]/div/p/span/span')

            if end_point.text == '마지막 항목입니다.':
                break
        except:
            pass
        

    place_columns = ['id', 'name', 'sub_name', 'addr', 'lat', 'lng']
    place_df = pd.DataFrame(columns = place_columns)

    review_columns = ['reivewId', 'content', 'image', 'star']
    review_df = pd.DataFrame(columns = review_columns)

    # 가게 정보 리스트 저장
    place_list = driver.find_elements(By.CSS_SELECTOR, 'div.Nv2PK.THOPZb.CpccDe > a.hfpxzc')
    driver.implicitly_wait(5)
    sleep(1)

    for i in range(len(place_list)):
        # 가게 클릭
        try:
            place_list[i].click()
            driver.implicitly_wait(10)
            sleep(2)
        except:
            print('해당 음식점 찾을 수 없음')
            continue

        # 위도 경도 가져오기
        location = get_location()
        
        # 가게 이름
        place_name = driver.find_element(By.XPATH, '//*[@id="QA0Szd"]/div/div/div[1]/div[3]/div/div[1]/div/div/div[2]/div[2]/div/div[1]/div[1]/h1').text
        
        # 가게 부가 정보
        place_sub_name = driver.find_element(By.XPATH, '//*[@id="QA0Szd"]/div/div/div[1]/div[3]/div/div[1]/div/div/div[2]/div[2]/div/div[1]/div[2]/div/div[2]/span/span/button').text

        # 가게 주소
        place_addr = driver.find_element(By.CSS_SELECTOR, 'div.Io6YTe.fontBodyMedium.kR99db').text
    

        place_sub_df = pd.DataFrame([[i, place_name, place_sub_name, place_addr, location['lat'], location['lng']]], columns=place_columns)

        place_df = pd.concat([place_df, place_sub_df], ignore_index=True)
        print(f"{i} 번째 가게 등록 --- 완료...")
        sleep(2)
        

        # 리뷰 탭 클릭
        review_button = driver.find_element(By.XPATH, '//*[@id="QA0Szd"]/div/div/div[1]/div[3]/div/div[1]/div/div/div[2]/div[3]/div/div/button[2]')
        review_button.click()
        driver.implicitly_wait(10)
        sleep(2)


        # 리뷰 글 전체
        # 리뷰 글 전체
        review_div = driver.find_elements(By.CSS_SELECTOR, 'div.jftiEf.fontBodyMedium ')[:5]

        for review in review_div:
            

            

            try:
                # 별점 가져오기
                review_star = review.find_element(By.CSS_SELECTOR, 'span.kvMYJc').accessible_name[-2]
                
                # 리뷰 글
                review_content = review.find_element(By.CSS_SELECTOR, 'span.wiI7pd')
                review_content_str = '' if review_content == None else review_content.text

                # 이미지 URL
                review_image = review.find_element(By.CSS_SELECTOR, 'div.KtCyie > button')
                url = review_image.get_attribute('style')
                url = url[url.find('https://') : url.find('");')]
            except:
                pass

            reivew_sub_df = pd.DataFrame([[i, review_content_str, url, review_star]], columns=review_columns)

            review_df = pd.concat([review_df, reivew_sub_df], ignore_index=True)
            
        print(f"{place_name} 리뷰 등록 --- 완료...")
        sleep(2)


        place_df.to_csv(f'C:/Users/Home/Documents/place{keyword}.csv', index=False, encoding='utf-8-sig')
        review_df.to_csv(f'C:/Users/Home/Documents/reivew{keyword}.csv', index=False, encoding='utf-8-sig')
# Out:
# 0 번째 가게 등록 --- 완료...
# 명월집 리뷰 등록 --- 완료...
# 1 번째 가게 등록 --- 완료...
# 일미정 리뷰 등록 --- 완료...
# 2 번째 가게 등록 --- 완료...
# 대전집 리뷰 등록 --- 완료...
# 3 번째 가게 등록 --- 완료...
# 향원 리뷰 등록 --- 완료...
# 4 번째 가게 등록 --- 완료...
# 노을밥상 리뷰 등록 --- 완료...
# 5 번째 가게 등록 --- 완료...
# 다복집 리뷰 등록 --- 완료...
# 6 번째 가게 등록 --- 완료...
# 금촌집 리뷰 등록 --- 완료...
# 7 번째 가게 등록 --- 완료...
# 덕적식당 리뷰 등록 --- 완료...
# 8 번째 가게 등록 --- 완료...
# 진흥각 리뷰 등록 --- 완료...
# 9 번째 가게 등록 --- 완료...
# 곡가 리뷰 등록 --- 완료...
# 10 번째 가게 등록 --- 완료...
# 신성루 리뷰 등록 --- 완료...
# 11 번째 가게 등록 --- 완료...
# 선미정 리뷰 등록 --- 완료...
# 12 번째 가게 등록 --- 완료...
# 혜빈장 리뷰 등록 --- 완료...
# 13 번째 가게 등록 --- 완료...
# 십리향 리뷰 등록 --- 완료...
# 14 번째 가게 등록 --- 완료...
# 메콩사롱 리뷰 등록 --- 완료...
# 15 번째 가게 등록 --- 완료...
# 일조용 리뷰 등록 --- 완료...
# 16 번째 가게 등록 --- 완료...
# 이화찹쌀순대 리뷰 등록 --- 완료...
# 17 번째 가게 등록 --- 완료...
# 도래순 리뷰 등록 --- 완료...
# 18 번째 가게 등록 --- 완료...
# 신승반점(新勝飯店) 리뷰 등록 --- 완료...
# 19 번째 가게 등록 --- 완료...
# 중앙옥 리뷰 등록 --- 완료...
# 20 번째 가게 등록 --- 완료...
# 동방식당 리뷰 등록 --- 완료...
# 21 번째 가게 등록 --- 완료...
# 만다복 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 23 번째 가게 등록 --- 완료...
# 중화방 인천점 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 25 번째 가게 등록 --- 완료...
# 경인면옥 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 27 번째 가게 등록 --- 완료...
# 담쟁이넝쿨 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 29 번째 가게 등록 --- 완료...
# 철이네손수제비랑칼국수 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 31 번째 가게 등록 --- 완료...
# 스시민 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 33 번째 가게 등록 --- 완료...
# 구운몽 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 35 번째 가게 등록 --- 완료...
# 우정일식 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 37 번째 가게 등록 --- 완료...
# 하늘채 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 39 번째 가게 등록 --- 완료...
# 인천집 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 41 번째 가게 등록 --- 완료...
# 연평도식당 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 43 번째 가게 등록 --- 완료...
# 고향정 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 45 번째 가게 등록 --- 완료...
# 국수평천하인천본점 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 47 번째 가게 등록 --- 완료...
# 개항로통닭 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 49 번째 가게 등록 --- 완료...
# 씨싸이드경양식 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 51 번째 가게 등록 --- 완료...
# 비스트로 쉐프 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 53 번째 가게 등록 --- 완료...
# 백야 갈비해장국 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 55 번째 가게 등록 --- 완료...
# 라파미글리아 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 57 번째 가게 등록 --- 완료...
# 온센텐동 신포 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 59 번째 가게 등록 --- 완료...
# 부안기사식당 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 61 번째 가게 등록 --- 완료...
# 제이콥스 핏제리아 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 63 번째 가게 등록 --- 완료...
# 삼강옥 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# 65 번째 가게 등록 --- 완료...
# 경남횟집 리뷰 등록 --- 완료...
# 해당 음식점 찾을 수 없음
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[9], line 83
#      80 location = get_location()
#      82 # 가게 이름
# ---> 83 place_name = driver.find_element(By.XPATH, '//*[@id="QA0Szd"]/div/div/div[1]/div[3]/div/div[1]/div/div/div[2]/div[2]/div/div[1]/div[1]/h1').text
#      85 # 가게 부가 정보
#      86 place_sub_name = driver.find_element(By.XPATH, '//*[@id="QA0Szd"]/div/div/div[1]/div[3]/div/div[1]/div/div/div[2]/div[2]/div/div[1]/div[2]/div/div[2]/span/span/button').text
#
# File c:\Users\Home\anaconda3\envs\firebase_app\lib\site-packages\selenium\webdriver\remote\webdriver.py:739, in WebDriver.find_element(self, by, value)
#     736     by = By.CSS_SELECTOR
#     737     value = f'[name="{value}"]'
# --> 739 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\Home\anaconda3\envs\firebase_app\lib\site-packages\selenium\webdriver\remote\webdriver.py:345, in WebDriver.execute(self, driver_command, params)
#     343 response = self.command_executor.execute(driver_command, params)
#     344 if response:
# --> 345     self.error_handler.check_response(response)
#     346     response["value"] = self._unwrap_value(response.get("value", None))
#     347     return response
#
# File c:\Users\Home\anaconda3\envs\firebase_app\lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: disconnected: received Inspector.detached event
#   (Session info: chrome=115.0.5790.173)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00007FF6B3154A62+57106]
# 	(No symbol) [0x00007FF6B30CCF52]
# 	(No symbol) [0x00007FF6B2F9E2CB]
# 	(No symbol) [0x00007FF6B2F8D13F]
# 	(No symbol) [0x00007FF6B2F8CA6E]
# 	(No symbol) [0x00007FF6B2F8BB4E]
# 	(No symbol) [0x00007FF6B2F8BAF3]
# 	(No symbol) [0x00007FF6B2F8A575]
# 	(No symbol) [0x00007FF6B2F8AEAE]
# 	(No symbol) [0x00007FF6B2FA0967]
# 	(No symbol) [0x00007FF6B2FA1198]
# 	(No symbol) [0x00007FF6B2FA3C5F]
# 	(No symbol) [0x00007FF6B2FA3D50]
# 	(No symbol) [0x00007FF6B2FD74E1]
# 	(No symbol) [0x00007FF6B2FD795C]
# 	(No symbol) [0x00007FF6B3010477]
# 	(No symbol) [0x00007FF6B2FF69FF]
# 	(No symbol) [0x00007FF6B300E522]
# 	(No symbol) [0x00007FF6B2FF6793]
# 	(No symbol) [0x00007FF6B2FCCE81]
# 	(No symbol) [0x00007FF6B2FCE064]
# 	GetHandleVerifier [0x00007FF6B3404222+2873042]
# 	GetHandleVerifier [0x00007FF6B3456590+3209792]
# 	GetHandleVerifier [0x00007FF6B344F3AF+3180639]
# 	GetHandleVerifier [0x00007FF6B31E5F25+652245]
# 	(No symbol) [0x00007FF6B30D8618]
# 	(No symbol) [0x00007FF6B30D47C4]
# 	(No symbol) [0x00007FF6B30D48BC]
# 	(No symbol) [0x00007FF6B30C4C33]
# 	BaseThreadInitThunk [0x00007FFB1BB27614+20]
# 	RtlUserThreadStart [0x00007FFB1D5226B1+33]
